# %%
# %matplotlib inline
import os
import sys

import time
import csv
import json
import numpy as np 

from src.utils.logger import *
from src.visualization.visualize import (
    plot_convergence, plot_box_scores, plot_time_comparison,
    plot_heatmap_ranking, plot_summary_table, plot_overall_comparison,
    plot_discrete_convergence, plot_discrete_bar,
    plot_pathfinding_grids, plot_pathfinding_metrics, plot_pathfinding_summary_table,
    plot_tsp_tour, plot_knapsack_items, plot_graph_coloring,
    plot_discrete_box, plot_scalability, plot_exploration_exploitation
)

save_dir = "output"

# %% [markdown]
# Discrete Problems Visualizations

# %%
# load the previous results from discrete problems
disc_results = load_discrete_benchmarks(save_dir="output")

# %% [markdown]
# 1. Convergence speed

# %%
plot_discrete_convergence(disc_results, save_dir)

# %% [markdown]
# 2. Result Visualization

# %%
plot_tsp_tour(disc_results, save_dir)
plot_graph_coloring(disc_results, save_dir)
plot_knapsack_items(disc_results, save_dir)
plot_discrete_bar(disc_results, save_dir)
# Out:
# /Users/thaihoang78/Project/Nature_Inspired_Algorithms/src/visualization/visualize.py:750: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(names, rotation=20, ha="right", fontsize=10)
# /Users/thaihoang78/Project/Nature_Inspired_Algorithms/src/visualization/visualize.py:750: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(names, rotation=20, ha="right", fontsize=10)
# /Users/thaihoang78/Project/Nature_Inspired_Algorithms/src/visualization/visualize.py:750: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(names, rotation=20, ha="right", fontsize=10)

# %% [markdown]
# 3. Robustness

# %%
plot_discrete_box(disc_results, save_dir="output")

# %% [markdown]
# Continuous Problems Visualizations

# %%
# load the previous results from continous problems
cont_results = load_continuous_benchmarks(save_dir)

# %% [markdown]
# 1. Convergence speed

# %%
plot_convergence(cont_results, save_dir)

# %% [markdown]
# 2. Robustness

# %%
plot_box_scores(cont_results, save_dir)

# %% [markdown]
# 3. Best / Average Solution Quality

# %%
plot_heatmap_ranking(cont_results, save_dir)
plot_summary_table(cont_results, save_dir)
plot_overall_comparison(cont_results, save_dir)

# %% [markdown]
# 4. Computational Complexity

# %%
plot_time_comparison(cont_results, save_dir)

# %% [markdown]
# 5. Scalability

# %%
# dimensions = 10, 30, 50
scalability = load_scalability_benchmarks(save_dir="output")
plot_scalability(scalability)

# %% [markdown]
# 6. Exploration and Exploitation

# %%
ee_results = load_exploration_exploitation_benchmarks(save_dir="output")
plot_exploration_exploitation(ee_results, save_dir = "output")
